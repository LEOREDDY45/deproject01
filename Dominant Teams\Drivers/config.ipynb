# %%
bronze='abfss://bronze@deproject01.dfs.core.windows.net'
silver='abfss://silver@deproject01.dfs.core.windows.net'
gold='abfss://gold@deproject01.dfs.core.windows.net'

# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *
from pyspark.sql.window import *
