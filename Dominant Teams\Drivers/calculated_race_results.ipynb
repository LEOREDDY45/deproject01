# %%
# %run ./config

# %%
results_df=spark.read.parquet(gold+'/race_results')
results_df=results_df.select('race_year', 
                             'team', 
                             'driver_name', 
                             'position', 
                             'points')\
                             .withColumn('calculated_points',  11-col('position'))

# %%
results_df=results_df.filter(col('position') <= 10)

# %%
results_df.write.mode('overwrite').parquet(gold+'/race_results_calculated')
